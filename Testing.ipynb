# %%
# !pip install -r requirements.txt
# Out:
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %% [markdown]
# Working on brazil to start

# %%
import scrapy
from scrapy.http import Request
from scrapy.selector import Selector
import requests
url = "https://climateactiontracker.org/countries/india/"
response = requests.get(url)
selector = Selector(text=response.text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[284], line 6
#       4 import requests
#       5 url = "https://climateactiontracker.org/countries/india/"
# ----> 6 response = requests.get(url)
#       7 selector = Selector(text=response.text)
#
# File ~/climate-data-web-scraping/scraping-env/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/climate-data-web-scraping/scraping-env/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/climate-data-web-scraping/scraping-env/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/climate-data-web-scraping/scraping-env/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/climate-data-web-scraping/scraping-env/lib/python3.13/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/climate-data-web-scraping/scraping-env/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/climate-data-web-scraping/scraping-env/lib/python3.13/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/climate-data-web-scraping/scraping-env/lib/python3.13/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
data = []

# %% [markdown]
# country Name

# %%
data.append(selector.css('h1::text').get())
selector.css('h1::text').get()
# Out:
# 'India'

# %% [markdown]
# Overall rating

# %%
data.append(selector.css('dd::text').get())
selector.css('dd::text').get()
# Out:
# 'Highly insufficient'

# %% [markdown]
# ### Indicators Row 2

# %% [markdown]
# each indicator stored in its own tile

# %%
tiles_row2 = selector.css('.ratings-matrix__second-row-cell')

# %% [markdown]
# we can iterate through each tile to extract data points

# %%
indicator_data = []
for tile in tiles_row2:

    term = tile.css('dl dt::text').get()

    if not term:
        ## most indicators stored under p tags under dt tag but not all
        term= tile.css('dl dt p::text').get()

    term_details = tile.css("i ::text").get()


    value = tile.css('dl dd b::text').get()

    metric = tile.css("dd i ::text").get()
    tile_contents =  {"term": term,"term_details": term_details, "value": value,"metric":metric}

    
    indicator_data.append(tile_contents)



# Print extracted data
for item in indicator_data:
    print(f"{item['term']}, {item["term_details"]}: {item['value']}, {item["metric"]}")
# Out:
# Policies and action , against fair share: Insufficient, < 3°C World
# Conditional NDC target, against modelled domestic pathways: Highly insufficient, < 4°C World
# Unconditional NDC target, against fair share: Insufficient, < 3°C World
# Climate finance, None: Not applicable, None

# %% [markdown]
# ### Indicators row 3 Net zero target

# %%
net_zero_tile = selector.css('.ratings-matrix__third-row')

# %%
term = net_zero_tile.css('dl dt::text').get()




bold_values = net_zero_tile.css('dl dd b::text').getall()
year = bold_values[0].strip()

value = bold_values[1].strip()

metric = net_zero_tile.css('dl dd p::text').getall()[1]

tile_contents =  {"term": term,"term_details": year, "value": value,"metric":metric}

indicator_data.append(tile_contents)

# %% [markdown]
# ### (unnofficial) fourth row tile land use and forestry

# %%
term = selector.css('.ratings-matrix__land_use_forestry dt::text').get().strip()
value = selector.css('.ratings-matrix__land_use_forestry dd b::text').get().strip()

tile_contents =  {"term": term,"term_details": None, "value": value,"metric":None}
indicator_data.append(tile_contents)

# %%
data.append(indicator_data)
data
# Out:
# ['India',
#  'Highly insufficient',
#  [{'term': 'Policies and action ',
#    'term_details': 'against fair share',
#    'value': 'Insufficient',
#    'metric': '< 3°C World'},
#   {'term': 'Conditional NDC target',
#    'term_details': 'against modelled domestic pathways',
#    'value': 'Highly insufficient',
#    'metric': '< 4°C World'},
#   {'term': 'Unconditional NDC target',
#    'term_details': 'against fair share',
#    'value': 'Insufficient',
#    'metric': '< 3°C World'},
#   {'term': 'Climate finance',
#    'term_details': None,
#    'value': 'Not applicable',
#    'metric': None},
#   {'term': 'Net zero target',
#    'term_details': '2070',
#    'value': 'Poor',
#    'metric': 'Comprehensiveness rated as'},
#   {'term': 'Land use & forestry',
#    'term_details': None,
#    'value': 'Not significant',
#    'metric': None}]]

# %%
# !scrapy crawl climate_action_tracker -O data/NEWoutput.json
# Out:
# 2025-02-14 20:46:18 [scrapy.utils.log] INFO: Scrapy 2.12.0 started (bot: climate_tracker)
# 2025-02-14 20:46:18 [scrapy.utils.log] INFO: Versions: lxml 5.3.1.0, libxml2 2.12.9, cssselect 1.2.0, parsel 1.10.0, w3lib 2.3.1, Twisted 24.11.0, Python 3.13.0 (main, Nov 21 2024, 14:21:20) [Clang 13.0.0 (clang-1300.0.27.3)], pyOpenSSL 25.0.0 (OpenSSL 3.4.1 11 Feb 2025), cryptography 44.0.1, Platform macOS-12.4-arm64-arm-64bit-Mach-O
# 2025-02-14 20:46:18 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-02-14 20:46:18 [asyncio] DEBUG: Using selector: KqueueSelector
# 2025-02-14 20:46:18 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2025-02-14 20:46:18 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2025-02-14 20:46:18 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2025-02-14 20:46:18 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2025-02-14 20:46:18 [scrapy.extensions.telnet] INFO: Telnet Password: ed1d2bd21464a483
# 2025-02-14 20:46:18 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2025-02-14 20:46:18 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'climate_tracker',
#  'DOWNLOAD_DELAY': 3,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'climate_tracker.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['climate_tracker.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor',
#  'USER_AGENT': 'LSE DS205 Student Spider (GitHub: @MaddoxLeigh) '
#                '(+https://lse-dsi.github.io/DS205)'}
# 2025-02-14 20:46:18 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-02-14 20:46:18 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-02-14 20:46:18 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2025-02-14 20:46:18 [scrapy.core.engine] INFO: Spider opened
# 2025-02-14 20:46:18 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-02-14 20:46:18 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2025-02-14 20:46:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://climateactiontracker.org/robots.txt> (referer: None)
# 2025-02-14 20:46:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://climateactiontracker.org/countries/brazil/> (referer: None)
# 2025-02-14 20:46:22 [scrapy.core.scraper] DEBUG: Scraped from <200 https://climateactiontracker.org/countries/brazil/>
# {'country_name': 'Brazil', 'overall_rating': 'Insufficient', 'indicators': [{'term': 'Policies and action ', 'term_details': 'against fair share', 'value': 'Insufficient', 'metric': '< 3°C World'}, {'term': 'NDC target', 'term_details': 'against modelled domestic pathways', 'value': 'Almost Sufficient', 'metric': '< 2°C World'}, {'term': 'NDC target', 'term_details': 'against fair share', 'value': 'Almost Sufficient', 'metric': '< 2°C World'}, {'term': 'Climate finance', 'term_details': None, 'value': 'Not applicable', 'metric': None}, {'term': 'Net zero target', 'term_details': '2050', 'value': 'Poor', 'metric': 'Comprehensiveness rated as'}, {'term': 'Land use & forestry', 'term_details': None, 'value': 'Source', 'metric': None}]}
# 2025-02-14 20:46:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://climateactiontracker.org/countries/china/> (referer: None)
# 2025-02-14 20:46:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://climateactiontracker.org/countries/china/>
# {'country_name': 'China', 'overall_rating': 'Highly insufficient', 'indicators': [{'term': 'Policies and action ', 'term_details': 'against fair share', 'value': 'Insufficient', 'metric': '< 3°C World'}, {'term': 'NDC target', 'term_details': 'against modelled domestic pathways', 'value': 'Highly insufficient', 'metric': '< 4°C World'}, {'term': 'NDC target', 'term_details': 'against fair share', 'value': 'Insufficient', 'metric': '< 3°C World'}, {'term': 'Climate finance', 'term_details': None, 'value': 'Not assessed', 'metric': None}, {'term': 'Net zero target', 'term_details': 'before 2060', 'value': 'Poor', 'metric': 'Comprehensiveness rated as'}, {'term': 'Land use & forestry', 'term_details': None, 'value': 'Not significant', 'metric': None}]}
# 2025-02-14 20:46:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://climateactiontracker.org/countries/usa/> (referer: None)
# 2025-02-14 20:46:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://climateactiontracker.org/countries/usa/>
# {'country_name': 'USA', 'overall_rating': 'Insufficient', 'indicators': [{'term': 'Policies and action', 'term_details': 'against modelled domestic pathways', 'value': 'Insufficient', 'metric': '< 3°C World'}, {'term': 'NDC target', 'term_details': 'against modelled domestic pathways', 'value': 'Almost Sufficient', 'metric': '< 2°C World'}, {'term': 'NDC target', 'term_details': 'against fair share', 'value': 'Insufficient', 'metric': '< 3°C World'}, {'term': 'Climate finance', 'term_details': None, 'value': 'Critically insufficient', 'metric': None}, {'term': 'Net zero target', 'term_details': '2050', 'value': 'Average', 'metric': 'Comprehensiveness rated as'}, {'term': 'Land use & forestry', 'term_details': None, 'value': 'Not significant', 'metric': None}]}
# 2025-02-14 20:46:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://climateactiontracker.org/countries/india/> (referer: None)
# 2025-02-14 20:46:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://climateactiontracker.org/countries/india/>
# {'country_name': 'India', 'overall_rating': 'Highly insufficient', 'indicators': [{'term': 'Policies and action ', 'term_details': 'against fair share', 'value': 'Insufficient', 'metric': '< 3°C World'}, {'term': 'Conditional NDC target', 'term_details': 'against modelled domestic pathways', 'value': 'Highly insufficient', 'metric': '< 4°C World'}, {'term': 'Unconditional NDC target', 'term_details': 'against fair share', 'value': 'Insufficient', 'metric': '< 3°C World'}, {'term': 'Climate finance', 'term_details': None, 'value': 'Not applicable', 'metric': None}, {'term': 'Net zero target', 'term_details': '2070', 'value': 'Poor', 'metric': 'Comprehensiveness rated as'}, {'term': 'Land use & forestry', 'term_details': None, 'value': 'Not significant', 'metric': None}]}
# 2025-02-14 20:46:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://climateactiontracker.org/countries/eu/> (referer: None)
# 2025-02-14 20:46:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://climateactiontracker.org/countries/eu/>
# {'country_name': 'EU', 'overall_rating': 'Insufficient', 'indicators': [{'term': 'Policies and action', 'term_details': 'against modelled domestic pathways', 'value': 'Insufficient', 'metric': '< 3°C World'}, {'term': 'NDC target', 'term_details': 'against modelled domestic pathways', 'value': 'Insufficient', 'metric': '< 3°C World'}, {'term': 'NDC target', 'term_details': 'against fair share', 'value': 'Insufficient', 'metric': '< 3°C World'}, {'term': 'Climate finance', 'term_details': None, 'value': 'Insufficient', 'metric': None}, {'term': 'Net zero target', 'term_details': '2050', 'value': 'Acceptable', 'metric': 'Comprehensiveness rated as'}, {'term': 'Land use & forestry', 'term_details': None, 'value': 'Not significant', 'metric': None}]}
# 2025-02-14 20:46:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://climateactiontracker.org/countries/germany/> (referer: None)
# 2025-02-14 20:46:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://climateactiontracker.org/countries/germany/>
# {'country_name': 'Germany', 'overall_rating': 'Insufficient', 'indicators': [{'term': 'Policies and action', 'term_details': 'against modelled domestic pathways', 'value': 'Almost Sufficient', 'metric': '< 2°C World'}, {'term': 'National target', 'term_details': 'against modelled domestic pathways', 'value': 'Almost Sufficient', 'metric': '< 2°C World'}, {'term': 'National target', 'term_details': 'against fair share', 'value': 'Insufficient', 'metric': '< 3°C World'}, {'term': 'Climate finance', 'term_details': None, 'value': 'Insufficient', 'metric': None}, {'term': 'Net zero target', 'term_details': '2045', 'value': 'Average', 'metric': 'Comprehensiveness rated as'}, {'term': 'Land use & forestry', 'term_details': None, 'value': 'Not significant', 'metric': None}]}
# 2025-02-14 20:46:46 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://climateactiontracker.org/countries/australia/> (referer: None)
# 2025-02-14 20:46:46 [scrapy.core.scraper] DEBUG: Scraped from <200 https://climateactiontracker.org/countries/australia/>
# {'country_name': 'Australia', 'overall_rating': 'Insufficient', 'indicators': [{'term': 'Policies and action', 'term_details': 'against modelled domestic pathways', 'value': 'Insufficient', 'metric': '< 3°C World'}, {'term': 'NDC target', 'term_details': 'against modelled domestic pathways', 'value': 'Insufficient', 'metric': '< 3°C World'}, {'term': 'NDC target', 'term_details': 'against fair share', 'value': 'Insufficient', 'metric': '< 3°C World'}, {'term': 'Climate finance', 'term_details': None, 'value': 'Critically insufficient', 'metric': None}, {'term': 'Net zero target', 'term_details': '2050', 'value': 'Poor', 'metric': 'Comprehensiveness rated as'}, {'term': 'Land use & forestry', 'term_details': None, 'value': 'Source', 'metric': None}]}
# 2025-02-14 20:46:49 [scrapy.downloadermiddlewares.redirect] DEBUG: Redirecting (301) to <GET https://climateactiontracker.org/countries/uk/> from <GET https://climateactiontracker.org/countries/united-kingdom/>
# 2025-02-14 20:46:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://climateactiontracker.org/countries/uk/> (referer: None)
# 2025-02-14 20:46:53 [scrapy.core.scraper] DEBUG: Scraped from <200 https://climateactiontracker.org/countries/uk/>
# {'country_name': 'United Kingdom', 'overall_rating': 'Insufficient', 'indicators': [{'term': 'Policies and action', 'term_details': 'against modelled domestic pathways', 'value': 'Insufficient', 'metric': '< 3°C World'}, {'term': 'NDC target', 'term_details': 'against modelled domestic pathways', 'value': 'Almost Sufficient', 'metric': '< 2°C World'}, {'term': 'NDC target', 'term_details': 'against fair share', 'value': 'Insufficient', 'metric': '< 3°C World'}, {'term': 'Climate finance', 'term_details': None, 'value': 'Highly insufficient', 'metric': None}, {'term': 'Net zero target', 'term_details': '2050', 'value': 'Acceptable', 'metric': 'Comprehensiveness rated as'}, {'term': 'Land use & forestry', 'term_details': None, 'value': 'Not significant', 'metric': None}]}
# 2025-02-14 20:46:53 [scrapy.core.engine] INFO: Closing spider (finished)
# 2025-02-14 20:46:53 [scrapy.extensions.feedexport] INFO: Stored json feed (8 items) in: data/NEWoutput.json
# 2025-02-14 20:46:53 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 2882,
#  'downloader/request_count': 10,
#  'downloader/request_method_count/GET': 10,
#  'downloader/response_bytes': 112375,
#  'downloader/response_count': 10,
#  'downloader/response_status_count/200': 9,
#  'downloader/response_status_count/301': 1,
#  'elapsed_time_seconds': 34.390393,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 2, 14, 20, 46, 53, 101683, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 582266,
#  'httpcompression/response_count': 8,
#  'item_scraped_count': 8,
#  'items_per_minute': None,
#  'log_count/DEBUG': 23,
#  'log_count/INFO': 11,
#  'memusage/max': 68239360,
#  'memusage/startup': 68239360,
#  'response_received_count': 9,
#  'responses_per_minute': None,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 9,
#  'scheduler/dequeued/memory': 9,
#  'scheduler/enqueued': 9,
#  'scheduler/enqueued/memory': 9,
#  'start_time': datetime.datetime(2025, 2, 14, 20, 46, 18, 711290, tzinfo=datetime.timezone.utc)}
# 2025-02-14 20:46:53 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# Final output from json

# %%
import json


with open("data/output.json", "r") as f:
    data = json.load(f)


print(json.dumps(data, indent=4))
# Out:
# [
#     {
#         "country_name": "Brazil",
#         "overall_rating": "Insufficient",
#         "indicators": [
#             {
#                 "term": "Policies and action ",
#                 "term_details": "against fair share",
#                 "value": "Insufficient",
#                 "metric": "< 3\u00b0C World"
#             },
#             {
#                 "term": "NDC target",
#                 "term_details": "against modelled domestic pathways",
#                 "value": "Almost Sufficient",
#                 "metric": "< 2\u00b0C World"
#             },
#             {
#                 "term": "NDC target",
#                 "term_details": "against fair share",
#                 "value": "Almost Sufficient",
#                 "metric": "< 2\u00b0C World"
#             },
#             {
#                 "term": "Climate finance",
#                 "term_details": null,
#                 "value": "Not applicable",
#                 "metric": null
#             },
#             {
#                 "term": "Net zero target",
#                 "term_details": "2050",
#                 "value": "Poor",
#                 "metric": "Comprehensiveness rated as"
#             },
#             {
#                 "term": "Land use & forestry",
#                 "term_details": null,
#                 "value": "Source",
#                 "metric": null
#             }
#         ]
#     },
#     {
#         "country_name": "China",
#         "overall_rating": "Highly insufficient",
#         "indicators": [
#             {
#                 "term": "Policies and action ",
#                 "term_details": "against fair share",
#                 "value": "Insufficient",
#                 "metric": "< 3\u00b0C World"
#             },
#             {
#                 "term": "NDC target",
#                 "term_details": "against modelled domestic pathways",
#                 "value": "Highly insufficient",
#                 "metric": "< 4\u00b0C World"
#             },
#             {
#                 "term": "NDC target",
#                 "term_details": "against fair share",
#                 "value": "Insufficient",
#                 "metric": "< 3\u00b0C World"
#             },
#             {
#                 "term": "Climate finance",
#                 "term_details": null,
#                 "value": "Not assessed",
#                 "metric": null
#             },
#             {
#                 "term": "Net zero target",
#                 "term_details": "before 2060",
#                 "value": "Poor",
#                 "metric": "Comprehensiveness rated as"
#             },
#             {
#                 "term": "Land use & forestry",
#                 "term_details": null,
#                 "value": "Not significant",
#                 "metric": null
#             }
#         ]
#     },
#     {
#         "country_name": "USA",
#         "overall_rating": "Insufficient",
#         "indicators": [
#             {
#                 "term": "Policies and action",
#                 "term_details": "against modelled domestic pathways",
#                 "value": "Insufficient",
#                 "metric": "< 3\u00b0C World"
#             },
#             {
#                 "term": "NDC target",
#                 "term_details": "against modelled domestic pathways",
#                 "value": "Almost Sufficient",
#                 "metric": "< 2\u00b0C World"
#             },
#             {
#                 "term": "NDC target",
#                 "term_details": "against fair share",
#                 "value": "Insufficient",
#                 "metric": "< 3\u00b0C World"
#             },
#             {
#                 "term": "Climate finance",
#                 "term_details": null,
#                 "value": "Critically insufficient",
#                 "metric": null
#             },
#             {
#                 "term": "Net zero target",
#                 "term_details": "2050",
#                 "value": "Average",
#                 "metric": "Comprehensiveness rated as"
#             },
#             {
#                 "term": "Land use & forestry",
#                 "term_details": null,
#                 "value": "Not significant",
#                 "metric": null
#             }
#         ]
#     },
#     {
#         "country_name": "India",
#         "overall_rating": "Highly insufficient",
#         "indicators": [
#             {
#                 "term": "Policies and action ",
#                 "term_details": "against fair share",
#                 "value": "Insufficient",
#                 "metric": "< 3\u00b0C World"
#             },
#             {
#                 "term": "Conditional NDC target",
#                 "term_details": "against modelled domestic pathways",
#                 "value": "Highly insufficient",
#                 "metric": "< 4\u00b0C World"
#             },
#             {
#                 "term": "Unconditional NDC target",
#                 "term_details": "against fair share",
#                 "value": "Insufficient",
#                 "metric": "< 3\u00b0C World"
#             },
#             {
#                 "term": "Climate finance",
#                 "term_details": null,
#                 "value": "Not applicable",
#                 "metric": null
#             },
#             {
#                 "term": "Net zero target",
#                 "term_details": "2070",
#                 "value": "Poor",
#                 "metric": "Comprehensiveness rated as"
#             },
#             {
#                 "term": "Land use & forestry",
#                 "term_details": null,
#                 "value": "Not significant",
#                 "metric": null
#             }
#         ]
#     },
#     {
#         "country_name": "EU",
#         "overall_rating": "Insufficient",
#         "indicators": [
#             {
#                 "term": "Policies and action",
#                 "term_details": "against modelled domestic pathways",
#                 "value": "Insufficient",
#                 "metric": "< 3\u00b0C World"
#             },
#             {
#                 "term": "NDC target",
#                 "term_details": "against modelled domestic pathways",
#                 "value": "Insufficient",
#                 "metric": "< 3\u00b0C World"
#             },
#             {
#                 "term": "NDC target",
#                 "term_details": "against fair share",
#                 "value": "Insufficient",
#                 "metric": "< 3\u00b0C World"
#             },
#             {
#                 "term": "Climate finance",
#                 "term_details": null,
#                 "value": "Insufficient",
#                 "metric": null
#             },
#             {
#                 "term": "Net zero target",
#                 "term_details": "2050",
#                 "value": "Acceptable",
#                 "metric": "Comprehensiveness rated as"
#             },
#             {
#                 "term": "Land use & forestry",
#                 "term_details": null,
#                 "value": "Not significant",
#                 "metric": null
#             }
#         ]
#     },
#     {
#         "country_name": "Germany",
#         "overall_rating": "Insufficient",
#         "indicators": [
#             {
#                 "term": "Policies and action",
#                 "term_details": "against modelled domestic pathways",
#                 "value": "Almost Sufficient",
#                 "metric": "< 2\u00b0C World"
#             },
#             {
#                 "term": "National target",
#                 "term_details": "against modelled domestic pathways",
#                 "value": "Almost Sufficient",
#                 "metric": "< 2\u00b0C World"
#             },
#             {
#                 "term": "National target",
#                 "term_details": "against fair share",
#                 "value": "Insufficient",
#                 "metric": "< 3\u00b0C World"
#             },
#             {
#                 "term": "Climate finance",
#                 "term_details": null,
#                 "value": "Insufficient",
#                 "metric": null
#             },
#             {
#                 "term": "Net zero target",
#                 "term_details": "2045",
#                 "value": "Average",
#                 "metric": "Comprehensiveness rated as"
#             },
#             {
#                 "term": "Land use & forestry",
#                 "term_details": null,
#                 "value": "Not significant",
#                 "metric": null
#             }
#         ]
#     },
#     {
#         "country_name": "Australia",
#         "overall_rating": "Insufficient",
#         "indicators": [
#             {
#                 "term": "Policies and action",
#                 "term_details": "against modelled domestic pathways",
#                 "value": "Insufficient",
#                 "metric": "< 3\u00b0C World"
#             },
#             {
#                 "term": "NDC target",
#                 "term_details": "against modelled domestic pathways",
#                 "value": "Insufficient",
#                 "metric": "< 3\u00b0C World"
#             },
#             {
#                 "term": "NDC target",
#                 "term_details": "against fair share",
#                 "value": "Insufficient",
#                 "metric": "< 3\u00b0C World"
#             },
#             {
#                 "term": "Climate finance",
#                 "term_details": null,
#                 "value": "Critically insufficient",
#                 "metric": null
#             },
#             {
#                 "term": "Net zero target",
#                 "term_details": "2050",
#                 "value": "Poor",
#                 "metric": "Comprehensiveness rated as"
#             },
#             {
#                 "term": "Land use & forestry",
#                 "term_details": null,
#                 "value": "Source",
#                 "metric": null
#             }
#         ]
#     },
#     {
#         "country_name": "United Kingdom",
#         "overall_rating": "Insufficient",
#         "indicators": [
#             {
#                 "term": "Policies and action",
#                 "term_details": "against modelled domestic pathways",
#                 "value": "Insufficient",
#                 "metric": "< 3\u00b0C World"
#             },
#             {
#                 "term": "NDC target",
#                 "term_details": "against modelled domestic pathways",
#                 "value": "Almost Sufficient",
#                 "metric": "< 2\u00b0C World"
#             },
#             {
#                 "term": "NDC target",
#                 "term_details": "against fair share",
#                 "value": "Insufficient",
#                 "metric": "< 3\u00b0C World"
#             },
#             {
#                 "term": "Climate finance",
#                 "term_details": null,
#                 "value": "Highly insufficient",
#                 "metric": null
#             },
#             {
#                 "term": "Net zero target",
#                 "term_details": "2050",
#                 "value": "Acceptable",
#                 "metric": "Comprehensiveness rated as"
#             },
#             {
#                 "term": "Land use & forestry",
#                 "term_details": null,
#                 "value": "Not significant",
#                 "metric": null
#             }
#         ]
#     }
# ]
