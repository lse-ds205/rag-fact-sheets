# %% [markdown]
# # CP1 Evaluation Performance
#
# Lets see how

# %%
# Import necessary modules
import sys
import os
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

# Get the absolute path of the project root directory
notebook_dir = Path(os.getcwd())  
project_root = notebook_dir.parent.parent  # Go up TWO levels instead of one

# Add project root to Python path
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from scripts.climate_policy_pipelines.cp1.pipeline import run_cp1a_assessment
from scripts.climate_policy_pipelines.cp1.pipeline import run_cp1a_assessment_large_context
from scripts.climate_policy_pipelines.cp1.pipeline import run_cp1b_assessment
# Out:
# Added c:\Users\User\GitHub\group-6-final-project to sys.path
# c:\Users\User\GitHub\group-6-final-project\group_rag.venv\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# Lets also load in the actual ASCOR assessment, or "ground truth":

# %%
# Load ASCOR data
ascor_ground_truth = pd.read_excel("ASCOR_assessments_results.xlsx")

# %% [markdown]
# # Run Assement

# %%
countries = ascor_ground_truth["Country"].unique().tolist()[:10]

results_data = []

for country in countries:
    # Get ASCOR ground truth for this country
    ascor_result = ascor_ground_truth[ascor_ground_truth["Country"] == country]
    
    # Run CP1A assessment and capture result
    cp1a_rag = run_cp1a_assessment(country=country, detailed=False)
    cp1a_large_context_rag = run_cp1a_assessment_large_context(country, detailed=False, print_results=False)
    cp1b_rag = run_cp1b_assessment(country, detailed=False, print_results=False)  # Uncomment if needed
    
    # Store results (adjust column names based on your ASCOR data structure)
    results_data.append({
        'Country': country,
        'ASCOR_True': ascor_result.iloc[0]['Assessment_Column'],  # Replace with actual column name
        'CP1A_Assessment': cp1a_rag, # Assuming this returns the assessment score/result
        'CP1A_Large_Context_Assessment': cp1a_large_context_rag,  # Assuming this returns the assessment score/result
        'CP1B_Assessment': cp1b_rag  # Uncomment if needed
    })
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# File c:\Users\User\GitHub\group-6-final-project\group_rag.venv\Lib\site-packages\transformers\utils\hub.py:424, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     422 if len(full_filenames) == 1:
#     423     # This is slightly better for only 1 file
# --> 424     hf_hub_download(
#     425         path_or_repo_id,
#     426         filenames[0],
#     427         subfolder=None if len(subfolder) == 0 else subfolder,
#     428         repo_type=repo_type,
#     429         revision=revision,
#     430         cache_dir=cache_dir,
#     431         user_agent=user_agent,
#     432         force_download=force_download,
#     433         proxies=proxies,
#     434         resume_download=resume_download,
#     435         token=token,
#     436         local_files_only=local_files_only,
#     437     )
#     438 else:
#
# File c:\Users\User\GitHub\group-6-final-project\group_rag.venv\Lib\site-packages\huggingface_hub\utils\_validators.py:106, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     105 if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 106     validate_repo_id(arg_value)
#     108 elif arg_name == "token" and arg_value is not None:
#
# File c:\Users\User\GitHub\group-6-final-project\group_rag.venv\Lib\site-packages\huggingface_hub\utils\_validators.py:154, in validate_repo_id(repo_id)
#     153 if repo_id.count("/") > 1:
# --> 154     raise HFValidationError(
#     155         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     156         f" '{repo_id}'. Use `repo_type` argument if needed."
#     157     )
#     159 if not REPO_ID_REGEX.match(repo_id):
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'local_model/climatebert/distilroberta-base-climate-f'. Use `repo_type` argument if needed.
#
# During handling of the above exception, another exception occurred:
#
# HFValidationError                         Traceback (most recent call last)
# Cell In[9], line 10
#       7 ascor_result = ascor_ground_truth[ascor_ground_truth["Country"] == country]
#       9 # Run CP1A assessment and capture result
# ---> 10 cp1a_rag = run_cp1a_assessment(country=country, detailed=False)
#      11 cp1a_large_context_rag = run_cp1a_assessment_large_context(country, detailed=False, print_results=False)
#      12 cp1b_rag = run_cp1b_assessment(country, detailed=False, print_results=False)  # Uncomment if needed
#
# File c:\Users\User\GitHub\group-6-final-project\scripts\climate_policy_pipelines\cp1\pipeline.py:189, in run_cp1a_assessment(country, detailed)
#     178 def run_cp1a_assessment(country=None, detailed=True):
#     179     """
#     180     Main function to run CP1a assessment with a single call
#     181
#    (...)    187         Assessment result (detailed dict or simple YES/NO string)
#     188     """
# --> 189     retrieved_chunks = get_chunks_for_cp1a(country)
#     191     if detailed:
#     192         result = cp1a_complete_assessment_chain_detailed.invoke(retrieved_chunks)
#
# File c:\Users\User\GitHub\group-6-final-project\scripts\climate_policy_pipelines\cp1\pipeline.py:78, in get_chunks_for_cp1a(country, k)
#      76 retrieved_chunks = []
#      77 for prompt in cp1a_prompts:
# ---> 78     chunks = do_retrieval(prompt, country=country, k=k)
#      79     retrieved_chunks.append(chunks)
#      81 return retrieved_chunks
#
# File c:\Users\User\GitHub\group-6-final-project\scripts\retrieval\retrieval_pipeline.py:152, in do_retrieval(prompt, country, k)
#     140 """
#     141 Simplified interface for document search.
#     142
#    (...)    149     list: List of chunk dictionaries in expected format
#     150 """
#     151 # Get DataFrame results
# --> 152 df_results = retrieve_relevant_chunks(prompt, country_code=country, top_k=k)
#     154 # Convert to expected list format
#     155 chunks = []
#
# File c:\Users\User\GitHub\group-6-final-project\scripts\retrieval\retrieval_pipeline.py:88, in retrieve_relevant_chunks(prompt, country_code, top_k, alpha)
#      86 # Load models
#      87 EMBEDDING_MODEL_LOCAL_DIR = os.getenv('EMBEDDING_MODEL_LOCAL_DIR')
# ---> 88 climatebert_tokenizer = AutoTokenizer.from_pretrained(EMBEDDING_MODEL_LOCAL_DIR)
#      89 climatebert_model = AutoModel.from_pretrained(EMBEDDING_MODEL_LOCAL_DIR)
#      90 word2vec_model = Word2Vec.load("./local_model/custom_word2vec_768.model")
#
# File c:\Users\User\GitHub\group-6-final-project\group_rag.venv\Lib\site-packages\transformers\models\auto\tokenization_auto.py:946, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     943     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     945 # Next, let's try to use the tokenizer_config file to get the tokenizer class.
# --> 946 tokenizer_config = get_tokenizer_config(pretrained_model_name_or_path, **kwargs)
#     947 if "_commit_hash" in tokenizer_config:
#     948     kwargs["_commit_hash"] = tokenizer_config["_commit_hash"]
#
# File c:\Users\User\GitHub\group-6-final-project\group_rag.venv\Lib\site-packages\transformers\models\auto\tokenization_auto.py:778, in get_tokenizer_config(pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, **kwargs)
#     775     token = use_auth_token
#     777 commit_hash = kwargs.get("_commit_hash", None)
# --> 778 resolved_config_file = cached_file(
#     779     pretrained_model_name_or_path,
#     780     TOKENIZER_CONFIG_FILE,
#     781     cache_dir=cache_dir,
#     782     force_download=force_download,
#     783     resume_download=resume_download,
#     784     proxies=proxies,
#     785     token=token,
#     786     revision=revision,
#     787     local_files_only=local_files_only,
#     788     subfolder=subfolder,
#     789     _raise_exceptions_for_gated_repo=False,
#     790     _raise_exceptions_for_missing_entries=False,
#     791     _raise_exceptions_for_connection_errors=False,
#     792     _commit_hash=commit_hash,
#     793 )
#     794 if resolved_config_file is None:
#     795     logger.info("Could not locate the tokenizer configuration file, will try to use the model config instead.")
#
# File c:\Users\User\GitHub\group-6-final-project\group_rag.venv\Lib\site-packages\transformers\utils\hub.py:266, in cached_file(path_or_repo_id, filename, **kwargs)
#     208 def cached_file(
#     209     path_or_repo_id: Union[str, os.PathLike],
#     210     filename: str,
#     211     **kwargs,
#     212 ) -> Optional[str]:
#     213     """
#     214     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     215
#    (...)    264     ```
#     265     """
# --> 266     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     267     file = file[0] if file is not None else file
#     268     return file
#
# File c:\Users\User\GitHub\group-6-final-project\group_rag.venv\Lib\site-packages\transformers\utils\hub.py:471, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     463     raise OSError(
#     464         f"{revision} is not a valid git identifier (branch name, tag name or commit id) that exists "
#     465         "for this model name. Check the model page at "
#     466         f"'https://huggingface.co/{path_or_repo_id}' for available revisions."
#     467     ) from e
#     469 # Now we try to recover if we can find all files correctly in the cache
#     470 resolved_files = [
# --> 471     _get_cache_file_to_return(path_or_repo_id, filename, cache_dir, revision) for filename in full_filenames
#     472 ]
#     473 if all(file is not None for file in resolved_files):
#     474     return resolved_files
#
# File c:\Users\User\GitHub\group-6-final-project\group_rag.venv\Lib\site-packages\transformers\utils\hub.py:134, in _get_cache_file_to_return(path_or_repo_id, full_filename, cache_dir, revision)
#     130 def _get_cache_file_to_return(
#     131     path_or_repo_id: str, full_filename: str, cache_dir: Union[str, Path, None] = None, revision: Optional[str] = None
#     132 ):
#     133     # We try to see if we have a cached version (not up to date):
# --> 134     resolved_file = try_to_load_from_cache(path_or_repo_id, full_filename, cache_dir=cache_dir, revision=revision)
#     135     if resolved_file is not None and resolved_file != _CACHED_NO_EXIST:
#     136         return resolved_file
#
# File c:\Users\User\GitHub\group-6-final-project\group_rag.venv\Lib\site-packages\huggingface_hub\utils\_validators.py:106, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     101 for arg_name, arg_value in chain(
#     102     zip(signature.parameters, args),  # Args values
#     103     kwargs.items(),  # Kwargs values
#     104 ):
#     105     if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 106         validate_repo_id(arg_value)
#     108     elif arg_name == "token" and arg_value is not None:
#     109         has_token = True
#
# File c:\Users\User\GitHub\group-6-final-project\group_rag.venv\Lib\site-packages\huggingface_hub\utils\_validators.py:154, in validate_repo_id(repo_id)
#     151     raise HFValidationError(f"Repo id must be a string, not {type(repo_id)}: '{repo_id}'.")
#     153 if repo_id.count("/") > 1:
# --> 154     raise HFValidationError(
#     155         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     156         f" '{repo_id}'. Use `repo_type` argument if needed."
#     157     )
#     159 if not REPO_ID_REGEX.match(repo_id):
#     160     raise HFValidationError(
#     161         "Repo id must use alphanumeric chars or '-', '_', '.', '--' and '..' are"
#     162         " forbidden, '-' and '.' cannot start or end the name, max length is 96:"
#     163         f" '{repo_id}'."
#     164     )
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'local_model/climatebert/distilroberta-base-climate-f'. Use `repo_type` argument if needed.

# %%
comparison_df = pd.DataFrame(results_data)

# Calculate accuracy for each assessment method
cp1a_accuracy = (comparison_df['ASCOR_True'] == comparison_df['CP1A_Assessment']).mean()
cp1a_large_accuracy = (comparison_df['ASCOR_True'] == comparison_df['CP1A_Large_Context_Assessment']).mean()
cp1b_accuracy = (comparison_df['ASCOR_True'] == comparison_df['CP1B_Assessment']).mean()

print(f"CP1A Accuracy: {cp1a_accuracy:.2%}")
print(f"CP1A Large Context Accuracy: {cp1a_large_accuracy:.2%}")
print(f"CP1B Accuracy: {cp1b_accuracy:.2%}")

# Create visualization
methods = ['CP1A', 'CP1A Large Context', 'CP1B']
accuracies = [cp1a_accuracy, cp1a_large_accuracy, cp1b_accuracy]

plt.figure(figsize=(10, 6))
bars = plt.bar(methods, accuracies, color=['skyblue', 'lightgreen', 'coral'])
plt.title('Assessment Method Accuracy Comparison')
plt.ylabel('Accuracy')
plt.ylim(0, 1)

# Add percentage labels on bars
for bar, acc in zip(bars, accuracies):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01, 
             f'{acc:.1%}', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# Display comparison DataFrame
print("\nDetailed Results:")
print(comparison_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 4
#       1 comparison_df = pd.DataFrame(results_data)
#       3 # Calculate accuracy for each assessment method
# ----> 4 cp1a_accuracy = (comparison_df['ASCOR_True'] == comparison_df['CP1A_Assessment']).mean()
#       5 cp1a_large_accuracy = (comparison_df['ASCOR_True'] == comparison_df['CP1A_Large_Context_Assessment']).mean()
#       6 cp1b_accuracy = (comparison_df['ASCOR_True'] == comparison_df['CP1B_Assessment']).mean()
#
# File c:\Users\User\GitHub\group-6-final-project\group_rag.venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\User\GitHub\group-6-final-project\group_rag.venv\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'ASCOR_True'
